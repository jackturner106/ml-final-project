# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (confusion_matrix, classification_report,
                             roc_curve, roc_auc_score)
import matplotlib.pyplot as plt
import DecompensationImputed

# %% [markdown]
# ## Data (with missingness indicators)

# %%
X, y, groups = DecompensationImputed.load_data(
    sample_size=10000, icu_vitals=True, top_n_labs=230, top_n_drugs=954,
    top_n_procedures=55, step_hours=48, missingness_indicators=True
)
# Out:
# Loading from cache: decomp_rolling_n10000_v1_l230_d954_p55_o48_pred24_s48_miss
# Returning 45820 windows with 863 features. y distribution:
# y
# 0    0.945941
# 1    0.054059
# Name: proportion, dtype: float64

# %%
# Drop one feature from each pair with |correlation| > 0.8
corr_matrix = X.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
to_drop = [col for col in upper.columns if any(upper[col] > 0.8)]

for col in to_drop:
    correlated_with = upper.index[upper[col] > 0.8].tolist()
    print(f"  Dropping {col:45s} (corr > 0.8 with {correlated_with})")

X = X.drop(columns=to_drop)
print(f"\nDropped {len(to_drop)} features, {X.shape[1]} remaining")
# Out:
#   Dropping lab_asparate_aminotransferase_(ast)           (corr > 0.8 with ['lab_alanine_aminotransferase_(alt)'])
#   Dropping lab_eag                                       (corr > 0.8 with ['lab_%_hemoglobin_a1c'])
#   Dropping lab_hemoglobin                                (corr > 0.8 with ['lab_hematocrit'])
#   Dropping lab_mcv                                       (corr > 0.8 with ['lab_mch'])
#   Dropping lab_n2_gene_ct                                (corr > 0.8 with ['lab_e_gene_ct'])
#   Dropping lab_n2_gene_endpt                             (corr > 0.8 with ['lab_e_gene_ct', 'lab_n2_gene_ct'])
#   Dropping lab_pt                                        (corr > 0.8 with ['lab_inr(pt)'])
#   Dropping lab_red_blood_cells                           (corr > 0.8 with ['lab_hematocrit', 'lab_hemoglobin'])
#   Dropping lab_required_o2                               (corr > 0.8 with ['lab_alveolar-arterial_gradient'])
#   Dropping lab_transferrin                               (corr > 0.8 with ['lab_iron_binding_capacity,_total'])
#   Dropping drug_sodium_chloride_0.9%__flush              (corr > 0.8 with ['drug_citrate_dextrose_3%_(acd-a)_crrt'])
#   Dropping procedure_8952                                (corr > 0.8 with ['procedure_8744'])
#   Dropping vital_respiratory_rate_missing                (corr > 0.8 with ['vital_heart_rate_missing'])
#   Dropping vital_spo2_missing                            (corr > 0.8 with ['vital_heart_rate_missing', 'vital_respiratory_rate_missing'])
#   Dropping vital_temperature_f_missing                   (corr > 0.8 with ['vital_heart_rate_missing', 'vital_respiratory_rate_missing', 'vital_spo2_missing'])
#   Dropping lab_absolute_eosinophil_count_missing         (corr > 0.8 with ['lab_absolute_basophil_count_missing'])
#   Dropping lab_absolute_lymphocyte_count_missing         (corr > 0.8 with ['lab_absolute_basophil_count_missing', 'lab_absolute_eosinophil_count_missing'])
#   Dropping lab_absolute_monocyte_count_missing           (corr > 0.8 with ['lab_absolute_basophil_count_missing', 'lab_absolute_eosinophil_count_missing', 'lab_absolute_lymphocyte_count_missing'])
#   Dropping lab_absolute_neutrophil_count_missing         (corr > 0.8 with ['lab_absolute_basophil_count_missing', 'lab_absolute_eosinophil_count_missing', 'lab_absolute_lymphocyte_count_missing', 'lab_absolute_monocyte_count_missing'])
#   Dropping lab_alkaline_phosphatase_missing              (corr > 0.8 with ['lab_alanine_aminotransferase_(alt)_missing'])
#   Dropping lab_asparate_aminotransferase_(ast)_missing   (corr > 0.8 with ['lab_alanine_aminotransferase_(alt)_missing', 'lab_alkaline_phosphatase_missing'])
#   Dropping lab_bands_missing                             (corr > 0.8 with ['lab_atypical_lymphocytes_missing'])
#   Dropping lab_bicarbonate_missing                       (corr > 0.8 with ['lab_anion_gap_missing'])
#   Dropping lab_bilirubin,_indirect_missing               (corr > 0.8 with ['lab_bilirubin,_direct_missing'])
#   Dropping lab_bilirubin,_total_missing                  (corr > 0.8 with ['lab_alanine_aminotransferase_(alt)_missing', 'lab_alkaline_phosphatase_missing', 'lab_asparate_aminotransferase_(ast)_missing'])
#   Dropping lab_c4_missing                                (corr > 0.8 with ['lab_c3_missing'])
#   Dropping lab_calcium,_total_missing                    (corr > 0.8 with ['lab_anion_gap_missing', 'lab_bicarbonate_missing'])
#   Dropping lab_calculated_total_co2_missing              (corr > 0.8 with ['lab_base_excess_missing'])
#   Dropping lab_chloride_missing                          (corr > 0.8 with ['lab_anion_gap_missing', 'lab_bicarbonate_missing', 'lab_calcium,_total_missing'])
#   Dropping lab_cholesterol,_ldl,_calculated_missing      (corr > 0.8 with ['lab_cholesterol,_hdl_missing'])
#   Dropping lab_cholesterol,_total_missing                (corr > 0.8 with ['lab_cholesterol,_hdl_missing', 'lab_cholesterol,_ldl,_calculated_missing'])
#   Dropping lab_cholesterol_ratio_(total/hdl)_missing     (corr > 0.8 with ['lab_cholesterol,_hdl_missing', 'lab_cholesterol,_ldl,_calculated_missing', 'lab_cholesterol,_total_missing'])
#   Dropping lab_cov8mc_missing                            (corr > 0.8 with ['lab_cov8ic_missing'])
#   Dropping lab_creatinine_missing                        (corr > 0.8 with ['lab_anion_gap_missing', 'lab_bicarbonate_missing', 'lab_calcium,_total_missing', 'lab_chloride_missing'])
#   Dropping lab_e_gene_endpt_missing                      (corr > 0.8 with ['lab_e_gene_ct_missing'])
#   Dropping lab_eag_missing                               (corr > 0.8 with ['lab_%_hemoglobin_a1c_missing'])
#   Dropping lab_eosinophils_missing                       (corr > 0.8 with ['lab_basophils_missing'])
#   Dropping lab_free_kappa/free_lambda_ratio_missing      (corr > 0.8 with ['lab_free_kappa_missing'])
#   Dropping lab_free_lambda_missing                       (corr > 0.8 with ['lab_free_kappa_missing', 'lab_free_kappa/free_lambda_ratio_missing'])
#   Dropping lab_glucose_missing                           (corr > 0.8 with ['lab_anion_gap_missing', 'lab_bicarbonate_missing', 'lab_calcium,_total_missing', 'lab_chloride_missing', 'lab_creatinine_missing'])
#   Dropping lab_hematocrit_missing                        (corr > 0.8 with ['lab_creatinine_missing'])
#   Dropping lab_hemoglobin_missing                        (corr > 0.8 with ['lab_creatinine_missing', 'lab_hematocrit_missing'])
#   Dropping lab_hpe3_missing                              (corr > 0.8 with ['lab_hpe1_missing'])
#   Dropping lab_hpe7_missing                              (corr > 0.8 with ['lab_hpe1_missing', 'lab_hpe3_missing'])
#   Dropping lab_i_missing                                 (corr > 0.8 with ['lab_h_missing'])
#   Dropping lab_immature_granulocytes_missing             (corr > 0.8 with ['lab_absolute_basophil_count_missing', 'lab_absolute_eosinophil_count_missing', 'lab_absolute_lymphocyte_count_missing', 'lab_absolute_monocyte_count_missing', 'lab_absolute_neutrophil_count_missing'])
#   Dropping lab_immunoglobulin_g_missing                  (corr > 0.8 with ['lab_immunoglobulin_a_missing'])
#   Dropping lab_immunoglobulin_m_missing                  (corr > 0.8 with ['lab_immunoglobulin_a_missing', 'lab_immunoglobulin_g_missing'])
#   Dropping lab_iron_missing                              (corr > 0.8 with ['lab_ferritin_missing'])
#   Dropping lab_iron_binding_capacity,_total_missing      (corr > 0.8 with ['lab_ferritin_missing', 'lab_iron_missing'])
#   Dropping lab_l_missing                                 (corr > 0.8 with ['lab_h_missing', 'lab_i_missing'])
#   Dropping lab_lactate_dehydrogenase,_ascites_missing    (corr > 0.8 with ['lab_glucose,_ascites_missing'])
#   Dropping lab_lactate_dehydrogenase,_pleural_missing    (corr > 0.8 with ['lab_glucose,_pleural_missing'])
#   Dropping lab_length_of_urine_collection_missing        (corr > 0.8 with ['lab_24_hr_creatinine_missing'])
#   Dropping lab_lymphocytes_missing                       (corr > 0.8 with ['lab_basophils_missing', 'lab_eosinophils_missing'])
#   Dropping lab_lymphs_missing                            (corr > 0.8 with ['lab_glucose,_csf_missing'])
#   Dropping lab_macrophages_missing                       (corr > 0.8 with ['lab_glucose,_pleural_missing', 'lab_lactate_dehydrogenase,_pleural_missing'])
#   Dropping lab_magnesium_missing                         (corr > 0.8 with ['lab_anion_gap_missing', 'lab_bicarbonate_missing', 'lab_calcium,_total_missing', 'lab_chloride_missing', 'lab_creatinine_missing', 'lab_glucose_missing'])
#   Dropping lab_mch_missing                               (corr > 0.8 with ['lab_creatinine_missing', 'lab_hematocrit_missing', 'lab_hemoglobin_missing'])
#   Dropping lab_mchc_missing                              (corr > 0.8 with ['lab_creatinine_missing', 'lab_hematocrit_missing', 'lab_hemoglobin_missing', 'lab_mch_missing'])
#   Dropping lab_mcv_missing                               (corr > 0.8 with ['lab_creatinine_missing', 'lab_hematocrit_missing', 'lab_hemoglobin_missing', 'lab_mch_missing', 'lab_mchc_missing'])
#   Dropping lab_metamyelocytes_missing                    (corr > 0.8 with ['lab_atypical_lymphocytes_missing', 'lab_bands_missing'])
#   Dropping lab_monocytes_missing                         (corr > 0.8 with ['lab_basophils_missing', 'lab_eosinophils_missing', 'lab_lymphocytes_missing'])
#   Dropping lab_myelocytes_missing                        (corr > 0.8 with ['lab_atypical_lymphocytes_missing', 'lab_bands_missing', 'lab_metamyelocytes_missing'])
#   Dropping lab_n2_gene_ct_missing                        (corr > 0.8 with ['lab_e_gene_ct_missing', 'lab_e_gene_endpt_missing'])
#   Dropping lab_n2_gene_endpt_missing                     (corr > 0.8 with ['lab_e_gene_ct_missing', 'lab_e_gene_endpt_missing', 'lab_n2_gene_ct_missing'])
#   Dropping lab_neutrophils_missing                       (corr > 0.8 with ['lab_basophils_missing', 'lab_eosinophils_missing', 'lab_lymphocytes_missing', 'lab_monocytes_missing'])
#   Dropping lab_pco2_missing                              (corr > 0.8 with ['lab_base_excess_missing', 'lab_calculated_total_co2_missing'])
#   Dropping lab_peep_missing                              (corr > 0.8 with ['lab_oxygen_missing'])
#   Dropping lab_phosphate_missing                         (corr > 0.8 with ['lab_anion_gap_missing', 'lab_bicarbonate_missing', 'lab_calcium,_total_missing', 'lab_chloride_missing', 'lab_creatinine_missing', 'lab_glucose_missing', 'lab_magnesium_missing'])
#   Dropping lab_platelet_count_missing                    (corr > 0.8 with ['lab_creatinine_missing', 'lab_hematocrit_missing', 'lab_hemoglobin_missing', 'lab_mch_missing', 'lab_mchc_missing', 'lab_mcv_missing'])
#   Dropping lab_po2_missing                               (corr > 0.8 with ['lab_base_excess_missing', 'lab_calculated_total_co2_missing', 'lab_pco2_missing'])
#   Dropping lab_potassium_missing                         (corr > 0.8 with ['lab_anion_gap_missing', 'lab_bicarbonate_missing', 'lab_calcium,_total_missing', 'lab_chloride_missing', 'lab_creatinine_missing', 'lab_glucose_missing', 'lab_magnesium_missing', 'lab_phosphate_missing'])
#   Dropping lab_pt_missing                                (corr > 0.8 with ['lab_inr(pt)_missing'])
#   Dropping lab_ptt_missing                               (corr > 0.8 with ['lab_inr(pt)_missing', 'lab_pt_missing'])
#   Dropping lab_rbc,_ascites_missing                      (corr > 0.8 with ['lab_mesothelial_cell_missing'])
#   Dropping lab_rbc,_csf_missing                          (corr > 0.8 with ['lab_glucose,_csf_missing', 'lab_lymphs_missing'])
#   Dropping lab_rbc,_pleural_missing                      (corr > 0.8 with ['lab_glucose,_pleural_missing', 'lab_lactate_dehydrogenase,_pleural_missing', 'lab_macrophages_missing'])
#   Dropping lab_rdw_missing                               (corr > 0.8 with ['lab_creatinine_missing', 'lab_hematocrit_missing', 'lab_hemoglobin_missing', 'lab_mch_missing', 'lab_mchc_missing', 'lab_mcv_missing', 'lab_platelet_count_missing'])
#   Dropping lab_rdw-sd_missing                            (corr > 0.8 with ['lab_h_missing', 'lab_i_missing', 'lab_l_missing'])
#   Dropping lab_red_blood_cells_missing                   (corr > 0.8 with ['lab_creatinine_missing', 'lab_hematocrit_missing', 'lab_hemoglobin_missing', 'lab_mch_missing', 'lab_mchc_missing', 'lab_mcv_missing', 'lab_platelet_count_missing', 'lab_rdw_missing'])
#   Dropping lab_required_o2_missing                       (corr > 0.8 with ['lab_alveolar-arterial_gradient_missing'])
#   Dropping lab_sodium_missing                            (corr > 0.8 with ['lab_anion_gap_missing', 'lab_bicarbonate_missing', 'lab_calcium,_total_missing', 'lab_chloride_missing', 'lab_creatinine_missing', 'lab_glucose_missing', 'lab_magnesium_missing', 'lab_phosphate_missing', 'lab_potassium_missing'])
#   Dropping lab_sodium,_whole_blood_missing               (corr > 0.8 with ['lab_chloride,_whole_blood_missing'])
#   Dropping lab_stx5_missing                              (corr > 0.8 with ['lab_stx4_missing'])
#   Dropping lab_tacrofk_missing                           (corr > 0.8 with ['drug_tacrolimus'])
#   Dropping lab_tidal_volume_missing                      (corr > 0.8 with ['lab_oxygen_missing', 'lab_peep_missing'])
#   Dropping lab_total_nucleated_cells,_ascites_missing    (corr > 0.8 with ['lab_mesothelial_cell_missing', 'lab_rbc,_ascites_missing'])
#   Dropping lab_total_nucleated_cells,_csf_missing        (corr > 0.8 with ['lab_glucose,_csf_missing', 'lab_lymphs_missing', 'lab_rbc,_csf_missing'])
#   Dropping lab_total_nucleated_cells,_pleural_missing    (corr > 0.8 with ['lab_glucose,_pleural_missing', 'lab_lactate_dehydrogenase,_pleural_missing', 'lab_macrophages_missing', 'lab_rbc,_pleural_missing'])
#   Dropping lab_total_protein,_ascites_missing            (corr > 0.8 with ['lab_glucose,_ascites_missing', 'lab_rbc,_ascites_missing', 'lab_total_nucleated_cells,_ascites_missing'])
#   Dropping lab_total_protein,_csf_missing                (corr > 0.8 with ['lab_glucose,_csf_missing', 'lab_lymphs_missing', 'lab_rbc,_csf_missing', 'lab_total_nucleated_cells,_csf_missing'])
#   Dropping lab_total_protein,_pleural_missing            (corr > 0.8 with ['lab_glucose,_pleural_missing', 'lab_lactate_dehydrogenase,_pleural_missing', 'lab_macrophages_missing', 'lab_rbc,_pleural_missing', 'lab_total_nucleated_cells,_pleural_missing'])
#   Dropping lab_total_protein,_urine_missing              (corr > 0.8 with ['lab_protein/creatinine_ratio_missing'])
#   Dropping lab_transferrin_missing                       (corr > 0.8 with ['lab_ferritin_missing', 'lab_iron_missing', 'lab_iron_binding_capacity,_total_missing'])
#   Dropping lab_urea_nitrogen_missing                     (corr > 0.8 with ['lab_anion_gap_missing', 'lab_bicarbonate_missing', 'lab_calcium,_total_missing', 'lab_chloride_missing', 'lab_creatinine_missing', 'lab_glucose_missing', 'lab_magnesium_missing', 'lab_phosphate_missing', 'lab_potassium_missing', 'lab_sodium_missing'])
#   Dropping lab_urine_volume_missing                      (corr > 0.8 with ['lab_24_hr_creatinine_missing', 'lab_length_of_urine_collection_missing'])
#   Dropping lab_utx2_missing                              (corr > 0.8 with ['lab_utx1_missing'])
#   Dropping lab_utx3_missing                              (corr > 0.8 with ['lab_utx1_missing', 'lab_utx2_missing'])
#   Dropping lab_utx4_missing                              (corr > 0.8 with ['lab_utx1_missing', 'lab_utx2_missing', 'lab_utx3_missing'])
#   Dropping lab_utx5_missing                              (corr > 0.8 with ['lab_utx1_missing', 'lab_utx2_missing', 'lab_utx3_missing', 'lab_utx4_missing'])
#   Dropping lab_utx6_missing                              (corr > 0.8 with ['lab_utx1_missing', 'lab_utx2_missing', 'lab_utx3_missing', 'lab_utx4_missing', 'lab_utx5_missing'])
#   Dropping lab_utx7_missing                              (corr > 0.8 with ['lab_utx1_missing', 'lab_utx2_missing', 'lab_utx3_missing', 'lab_utx4_missing', 'lab_utx5_missing', 'lab_utx6_missing'])
#   Dropping lab_wbc_missing                               (corr > 0.8 with ['lab_rbc_missing'])
#   Dropping lab_white_blood_cells_missing                 (corr > 0.8 with ['lab_creatinine_missing', 'lab_hematocrit_missing', 'lab_hemoglobin_missing', 'lab_mch_missing', 'lab_mchc_missing', 'lab_mcv_missing', 'lab_platelet_count_missing', 'lab_rdw_missing', 'lab_red_blood_cells_missing'])
#
# Dropped 105 features, 758 remaining

# %%
# 80/20 patient-level split
unique_subjects = groups.unique()
np.random.seed(42)
np.random.shuffle(unique_subjects)
split = int(0.8 * len(unique_subjects))
train_subjects = set(unique_subjects[:split])
train_mask = groups.isin(train_subjects)

X_train, X_test = X[train_mask], X[~train_mask]
y_train, y_test = y[train_mask], y[~train_mask]

print(f"Train: {X_train.shape} ({y_train.mean():.4%} positive)")
print(f"Test:  {X_test.shape} ({y_test.mean():.4%} positive)")
# Out:
# Train: (36615, 758) (5.4213% positive)
# Test:  (9205, 758) (5.3449% positive)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# %% [markdown]
# ## Logistic Regression (scaled and class weighted)

# %%
model = LogisticRegression(C=0.2, class_weight='balanced', max_iter=10000)
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(C=0.2, class_weight='balanced', max_iter=10000)

# %%
y_pred  = model.predict(X_test_scaled)
y_proba = model.predict_proba(X_test_scaled)[:, 1]

cm = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = cm.ravel()
tpr = tp / (tp + fn)
fpr = fp / (fp + tn)
tnr = tn / (tn + fp)
ppv = tp / (tp + fp)

print("Confusion matrix:")
print(f"  {'':12s}  Pred 0   Pred 1")
print(f"  {'Actual 0':12s}  {tn:>6}   {fp:>6}   (specificity {tnr:.3f})")
print(f"  {'Actual 1':12s}  {fn:>6}   {tp:>6}   (sensitivity {tpr:.3f})")
print()
print(f"TPR (sensitivity):  {tpr:.3f}")
print(f"FPR (fall-out):     {fpr:.3f}")
print(f"Precision:          {ppv:.3f}")
print(f"ROC-AUC:            {roc_auc_score(y_test, y_proba):.3f}")
print()
print(classification_report(y_test, y_pred, target_names=['Survived', 'Died']))

fig, axes = plt.subplots(1, 2, figsize=(10, 4))

im = axes[0].imshow(cm, cmap='Blues')
axes[0].set_xticks([0, 1]); axes[0].set_yticks([0, 1])
axes[0].set_xticklabels(['Pred 0', 'Pred 1'])
axes[0].set_yticklabels(['Actual 0', 'Actual 1'])
for i in range(2):
    for j in range(2):
        axes[0].text(j, i, cm[i, j], ha='center', va='center',
                     color='white' if cm[i, j] > cm.max() / 2 else 'black', fontsize=14)
axes[0].set_title('Confusion Matrix')
plt.colorbar(im, ax=axes[0])

fpr_curve, tpr_curve, _ = roc_curve(y_test, y_proba)
auc = roc_auc_score(y_test, y_proba)
axes[1].plot(fpr_curve, tpr_curve, lw=2, label=f'AUC = {auc:.3f}')
axes[1].plot([0, 1], [0, 1], 'k--', lw=1)
axes[1].scatter([fpr], [tpr], color='red', zorder=5, label=f'Operating point\nFPR={fpr:.2f}, TPR={tpr:.2f}')
axes[1].set_xlabel('False Positive Rate'); axes[1].set_ylabel('True Positive Rate')
axes[1].set_title('ROC Curve'); axes[1].legend(fontsize=8)

plt.tight_layout()
plt.show()
# Out:
# Confusion matrix:
#                 Pred 0   Pred 1
#   Actual 0        6430     2283   (specificity 0.738)
#   Actual 1         156      336   (sensitivity 0.683)
#
# TPR (sensitivity):  0.683
# FPR (fall-out):     0.262
# Precision:          0.128
# ROC-AUC:            0.778
#
#               precision    recall  f1-score   support
#
#     Survived       0.98      0.74      0.84      8713
#         Died       0.13      0.68      0.22       492
#
#     accuracy                           0.74      9205
#    macro avg       0.55      0.71      0.53      9205
# weighted avg       0.93      0.74      0.81      9205

# %%
coef_series = pd.Series(model.coef_[0], index=X.columns)
print("Top 20 POSITIVE coefficients:")
print(coef_series.sort_values(ascending=False).head(20).to_string())
print("\nTop 20 NEGATIVE coefficients:")
print(coef_series.sort_values(ascending=True).head(20).to_string())
# Out:
# Top 20 POSITIVE coefficients:
# lab_sodium                                       0.460163
# lab_h_missing                                    0.380021
# hours_since_admission                            0.376192
# drug_morphine_sulfate                            0.375665
# anchor_age                                       0.300152
# lab_ethanol                                      0.280484
# drug_scopolamine_patch                           0.252764
# lab_pco2                                         0.239768
# drug_acetaminophen_iv                            0.218886
# lab_anion_gap_missing                            0.216865
# lab_free_kappa                                   0.192567
# lab_lactate                                      0.183882
# admission_type_EW EMER.                          0.182612
# lab_blasts                                       0.181125
# lab_potassium                                    0.171368
# lab_chloride,_whole_blood_missing                0.167433
# lab_ph_missing                                   0.166851
# drug_chlorhexidine_gluconate_0.12%_oral_rinse    0.158841
# lab_neutrophils                                  0.158287
# drug_albuterol_0.083%_neb_soln                   0.155395
#
# Top 20 NEGATIVE coefficients:
# admission_location_INTERNAL TRANSFER TO OR FROM PSYCH   -0.631571
# procedure_5A1955Z                                       -0.513961
# lab_chloride                                            -0.482247
# lab_free_kappa/free_lambda_ratio                        -0.453732
# procedure_9672                                          -0.442429
# lab_base_excess_missing                                 -0.386811
# drug_dibucaine                                          -0.373539
# lab_bicarbonate                                         -0.346920
# procedure_966                                           -0.335529
# procedure_3E0G76Z                                       -0.323298
# vital_heart_rate_missing                                -0.321318
# procedure_10D00Z1                                       -0.282089
# procedure_5491                                          -0.271089
# procedure_02HV33Z                                       -0.266971
# procedure_3995                                          -0.253983
# procedure_0331                                          -0.244415
# drug_tacrolimus_suspension                              -0.242697
# lab_amylase,_ascites                                    -0.242343
# procedure_4513                                          -0.227860
# drug_cyclophosphamide                                   -0.220026

# %% [markdown]
# ## Lasso Path

# %%
# Lasso path: fit individual models at 30 regularization strengths (parallelized)
from joblib import Parallel, delayed

Cs = np.logspace(-4, 0, 30)

def fit_one(C):
    lr = LogisticRegression(C=C, l1_ratio=1, solver='saga', max_iter=1000, class_weight='balanced')
    lr.fit(X_train_scaled, y_train)
    auc = roc_auc_score(y_test, lr.predict_proba(X_test_scaled)[:, 1])
    return lr.coef_[0], auc, lr

results = Parallel(n_jobs=12, verbose=10)(delayed(fit_one)(C) for C in Cs)
coefs_path, aucs, models = zip(*results)
coefs_path = np.array(coefs_path).T
aucs = np.array(aucs)

# Select best model by test AUC
best_idx = np.argmax(aucs)
best_C = Cs[best_idx]
model = models[best_idx]
print(f"Best C: {best_C:.6f} (AUC: {aucs[best_idx]:.4f})")
print(f"Non-zero coefficients: {np.sum(model.coef_[0] != 0)} / {len(model.coef_[0])}")

# --- Lasso path plot ---
alphas_plot = 1 / Cs
top_n = 15
top_idx = np.argsort(np.abs(coefs_path).max(axis=1))[-top_n:]

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for i in range(coefs_path.shape[0]):
    axes[0].plot(alphas_plot, coefs_path[i], color='lightgray', linewidth=0.6, zorder=1)

cmap = plt.cm.tab20
handles, labels = [], []
for rank, i in enumerate(top_idx):
    color = cmap(rank / top_n)
    line, = axes[0].plot(alphas_plot, coefs_path[i], color=color, linewidth=1.8, zorder=2)
    handles.append(line)
    labels.append(X.columns[i])

best_lambda = 1 / best_C
axes[0].axvline(best_lambda, color='red', linestyle='--', linewidth=1.2, zorder=3)
handles.append(plt.Line2D([0], [0], color='red', linestyle='--', linewidth=1.2))
labels.append(f'Best lambda = {best_lambda:.4f}')

axes[0].set_xscale('log')
axes[0].axhline(0, color='black', linewidth=0.8)
axes[0].set_xlabel('Regularization (lambda = 1/C)')
axes[0].set_ylabel('Coefficient value')
axes[0].set_title('L1 Logistic Regression Path (with missingness)')
axes[0].legend(handles, labels, fontsize=6, loc='upper left',
               bbox_to_anchor=(1.01, 1), borderaxespad=0, frameon=True)

axes[1].plot(alphas_plot, aucs)
axes[1].axvline(best_lambda, color='red', linestyle='--')
axes[1].set_xscale('log')
axes[1].set_xlabel('Regularization (lambda = 1/C)')
axes[1].set_ylabel('ROC AUC')
axes[1].set_title('Test AUC vs Regularization')

plt.tight_layout()
plt.savefig('results/decompensation_lasso_path_missingness.png', dpi=120, bbox_inches='tight')
plt.show()
# Out:
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done   1 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=12)]: Done  11 out of  30 | elapsed:  2.2min remaining:  3.8min
# [Parallel(n_jobs=12)]: Done  15 out of  30 | elapsed:  5.2min remaining:  5.2min
# /nix/store/0wq9dh3n1nl2x4mx3ld8azmvpli7pk1l-python3-3.13.12-env/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /nix/store/0wq9dh3n1nl2x4mx3ld8azmvpli7pk1l-python3-3.13.12-env/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /nix/store/0wq9dh3n1nl2x4mx3ld8azmvpli7pk1l-python3-3.13.12-env/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Parallel(n_jobs=12)]: Done  19 out of  30 | elapsed: 11.7min remaining:  6.8min
# /nix/store/0wq9dh3n1nl2x4mx3ld8azmvpli7pk1l-python3-3.13.12-env/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /nix/store/0wq9dh3n1nl2x4mx3ld8azmvpli7pk1l-python3-3.13.12-env/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /nix/store/0wq9dh3n1nl2x4mx3ld8azmvpli7pk1l-python3-3.13.12-env/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /nix/store/0wq9dh3n1nl2x4mx3ld8azmvpli7pk1l-python3-3.13.12-env/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Parallel(n_jobs=12)]: Done  23 out of  30 | elapsed: 12.9min remaining:  3.9min
# /nix/store/0wq9dh3n1nl2x4mx3ld8azmvpli7pk1l-python3-3.13.12-env/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /nix/store/0wq9dh3n1nl2x4mx3ld8azmvpli7pk1l-python3-3.13.12-env/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /nix/store/0wq9dh3n1nl2x4mx3ld8azmvpli7pk1l-python3-3.13.12-env/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /nix/store/0wq9dh3n1nl2x4mx3ld8azmvpli7pk1l-python3-3.13.12-env/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Parallel(n_jobs=12)]: Done  27 out of  30 | elapsed: 14.1min remaining:  1.6min
# /nix/store/0wq9dh3n1nl2x4mx3ld8azmvpli7pk1l-python3-3.13.12-env/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /nix/store/0wq9dh3n1nl2x4mx3ld8azmvpli7pk1l-python3-3.13.12-env/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /nix/store/0wq9dh3n1nl2x4mx3ld8azmvpli7pk1l-python3-3.13.12-env/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Parallel(n_jobs=12)]: Done  30 out of  30 | elapsed: 15.5min finished
# Best C: 0.006210 (AUC: 0.8045)
# Non-zero coefficients: 322 / 758

# %% [markdown]
# ## Reload with Lasso-selected features only

# %%
# Extract nonzero features from best lasso model
coef_series = pd.Series(model.coef_[0], index=X.columns)
keep = coef_series[coef_series != 0].index.tolist()
all_feats = coef_series.index.tolist()
total_labs = sum(1 for f in all_feats if f.startswith('lab_') and not f.endswith('_missing'))
total_lab_miss = sum(1 for f in all_feats if f.startswith('lab_') and f.endswith('_missing'))
total_drugs = sum(1 for f in all_feats if f.startswith('drug_'))
total_procs = sum(1 for f in all_feats if f.startswith('procedure_'))
total_vitals = sum(1 for f in all_feats if f.startswith('vital_') and not f.endswith('_missing'))
total_vital_miss = sum(1 for f in all_feats if f.startswith('vital_') and f.endswith('_missing'))
total_other = len(all_feats) - total_labs - total_lab_miss - total_drugs - total_procs - total_vitals - total_vital_miss
print(f"Lasso selected {len(keep)} / {len(coef_series)} features")
print(f"  Labs: {sum(1 for f in keep if f.startswith('lab_') and not f.endswith('_missing'))} / {total_labs}")
print(f"  Lab missingness: {sum(1 for f in keep if f.startswith('lab_') and f.endswith('_missing'))} / {total_lab_miss}")
print(f"  Drugs: {sum(1 for f in keep if f.startswith('drug_'))} / {total_drugs}")
print(f"  Procedures: {sum(1 for f in keep if f.startswith('procedure_'))} / {total_procs}")
print(f"  Vitals: {sum(1 for f in keep if f.startswith('vital_') and not f.endswith('_missing'))} / {total_vitals}")
print(f"  Vital missingness: {sum(1 for f in keep if f.startswith('vital_') and f.endswith('_missing'))} / {total_vital_miss}")
print(f"  Other: {sum(1 for f in keep if not any(f.startswith(p) for p in ['lab_', 'drug_', 'procedure_', 'vital_']))} / {total_other}")

# Save for use in other notebooks (e.g. random forest)
pd.Series(keep).to_csv('results/lasso_selected_features_missingness.csv', index=False, header=False)
print(f"Saved to results/lasso_selected_features_missingness.csv")
# Out:
# Lasso selected 322 / 758 features
#   Labs: 80 / 201
#   Lab missingness: 38 / 121
#   Drugs: 157 / 343
#   Procedures: 33 / 54
#   Vitals: 2 / 4
#   Vital missingness: 1 / 1
#   Other: 11 / 34
# Saved to results/lasso_selected_features_missingness.csv

# %%
# Reload with more data, only loading Lasso-selected features
X, y, groups = DecompensationImputed.load_data(
    sample_size=100000, icu_vitals=True,
    top_n_labs=230, top_n_drugs=954, top_n_procedures=55,
    step_hours=48, keep_features=keep, missingness_indicators=True
)

X = X[[c for c in keep if c in X.columns]]
print(f"Final feature matrix: {X.shape}")
# Out:
# Sampled 58750 admissions (8750 deaths, 50000 survived)
# Avg length of stay: 190.7 hours (7.9 days)
# Generated 205098 windows from 58750 admissions (3.5 windows/admission)
# Positive windows: 4373 (2.1322%)
#   Labs filtered to 93 by keep_features
#   Drugs filtered to 508 by keep_features
#   Procedures filtered to 34 by keep_features
# Cached to: decomp_rolling_n100000_v1_l230_d954_p55_o48_pred24_s48_kf336_miss
# Returning 205098 windows with 406 features. y distribution:
# y
# 0    0.978678
# 1    0.021322
# Name: proportion, dtype: float64
# Final feature matrix: (205098, 309)

# %%
# Re-split and re-scale with the larger dataset
unique_subjects = groups.unique()
np.random.seed(42)
np.random.shuffle(unique_subjects)
split = int(0.8 * len(unique_subjects))
train_subjects = set(unique_subjects[:split])
train_mask = groups.isin(train_subjects)

X_train, X_test = X[train_mask], X[~train_mask]
y_train, y_test = y[train_mask], y[~train_mask]

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(f"Train: {X_train.shape} ({y_train.mean():.4%} positive)")
print(f"Test:  {X_test.shape} ({y_test.mean():.4%} positive)")
# Out:
# Train: (164223, 309) (2.1325% positive)
# Test:  (40875, 309) (2.1309% positive)

# %%
# Refit with best C from lasso path on the larger, feature-reduced dataset
model = LogisticRegression(C=best_C, l1_ratio=1, solver='saga', max_iter=5000, class_weight='balanced')
model.fit(X_train_scaled, y_train)
print(f"Refit with C={best_C:.6f}, non-zero: {np.sum(model.coef_[0] != 0)} / {len(model.coef_[0])}")
# Out:
# Refit with C=0.006210, non-zero: 284 / 309
# /nix/store/82d4idzilks59f2waanikzv3an5cn8q0-python3-3.13.12-env/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
import joblib
joblib.dump(model, 'results/decompensation_lasso_model_missingness.joblib')
# Out:
# ['results/decompensation_lasso_model_missingness.joblib']

# %%
coef_series = pd.Series(model.coef_[0], index=X.columns)
coef_series = coef_series.sort_values()
coef_series.to_csv('results/decompensation_coef_series_missingness.csv')

# %%
y_pred  = model.predict(X_test_scaled)
y_proba = model.predict_proba(X_test_scaled)[:, 1]

cm = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = cm.ravel()
tpr = tp / (tp + fn)
fpr = fp / (fp + tn)
tnr = tn / (tn + fp)
ppv = tp / (tp + fp)

print("Confusion matrix:")
print(f"  {'':12s}  Pred 0   Pred 1")
print(f"  {'Actual 0':12s}  {tn:>6}   {fp:>6}   (specificity {tnr:.3f})")
print(f"  {'Actual 1':12s}  {fn:>6}   {tp:>6}   (sensitivity {tpr:.3f})")
print()
print(f"TPR (sensitivity):  {tpr:.3f}")
print(f"FPR (fall-out):     {fpr:.3f}")
print(f"Precision:          {ppv:.3f}")
print(f"ROC-AUC:            {roc_auc_score(y_test, y_proba):.3f}")
print()
print(classification_report(y_test, y_pred, target_names=['Survived', 'Died']))

fig, axes = plt.subplots(1, 2, figsize=(10, 4))

im = axes[0].imshow(cm, cmap='Blues')
axes[0].set_xticks([0, 1]); axes[0].set_yticks([0, 1])
axes[0].set_xticklabels(['Pred 0', 'Pred 1'])
axes[0].set_yticklabels(['Actual 0', 'Actual 1'])
for i in range(2):
    for j in range(2):
        axes[0].text(j, i, cm[i, j], ha='center', va='center',
                     color='white' if cm[i, j] > cm.max() / 2 else 'black', fontsize=14)
axes[0].set_title('Confusion Matrix')
plt.colorbar(im, ax=axes[0])

fpr_curve, tpr_curve, _ = roc_curve(y_test, y_proba)
auc = roc_auc_score(y_test, y_proba)
axes[1].plot(fpr_curve, tpr_curve, lw=2, label=f'AUC = {auc:.3f}')
axes[1].plot([0, 1], [0, 1], 'k--', lw=1)
axes[1].scatter([fpr], [tpr], color='red', zorder=5, label=f'Operating point\nFPR={fpr:.2f}, TPR={tpr:.2f}')
axes[1].set_xlabel('False Positive Rate'); axes[1].set_ylabel('True Positive Rate')
axes[1].set_title('ROC Curve'); axes[1].legend(fontsize=8)

plt.tight_layout()
plt.savefig('results/decompensation_lasso_results_missingness.png', dpi=120, bbox_inches='tight')
plt.show()
# Out:
# Confusion matrix:
#                 Pred 0   Pred 1
#   Actual 0       32675     7329   (specificity 0.817)
#   Actual 1         173      698   (sensitivity 0.801)
#
# TPR (sensitivity):  0.801
# FPR (fall-out):     0.183
# Precision:          0.087
# ROC-AUC:            0.889
#
#               precision    recall  f1-score   support
#
#     Survived       0.99      0.82      0.90     40004
#         Died       0.09      0.80      0.16       871
#
#     accuracy                           0.82     40875
#    macro avg       0.54      0.81      0.53     40875
# weighted avg       0.98      0.82      0.88     40875

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

coef_series = pd.Series(model.coef_[0], index=X.columns)
top__neg_coef = coef_series[coef_series != 0].sort_values(ascending=True).head(20)
signed_top = coef_series[top__neg_coef.index]
axes[0].barh(signed_top.index[::-1], signed_top.values[::-1], color='tomato')
axes[0].axvline(0, color='black', linewidth=0.8)
axes[0].set_xlabel('Logistic Regression Coefficient')
axes[0].set_title('Negative Features by Coefficient')
axes[0].tick_params(axis='y', labelsize=7)

coef_series = pd.Series(model.coef_[0], index=X.columns)
top_pos_coef = coef_series[coef_series != 0].sort_values(ascending=False).head(20)
signed_top = coef_series[top_pos_coef.index]
axes[1].barh(signed_top.index[::-1], signed_top.values[::-1], color='steelblue')
axes[1].axvline(0, color='black', linewidth=0.8)
axes[1].set_xlabel('Logistic Regression Coefficient')
axes[1].set_title('Positive Features by Coefficient')
axes[1].tick_params(axis='y', labelsize=7)
axes[1].yaxis.set_label_position("right")
axes[1].yaxis.tick_right()

plt.tight_layout()
plt.show()

# %%
coef_series = pd.Series(model.coef_[0], index=X.columns)
print("Top 20 POSITIVE coefficients:")
print(coef_series.sort_values(ascending=False).head(20).to_string())
print("\nTop 20 NEGATIVE coefficients:")
print(coef_series.sort_values(ascending=True).head(20).to_string())
# Out:
# Top 20 POSITIVE coefficients:
# anchor_age                                                   0.592355
# lab_anion_gap_missing                                        0.326865
# drug_morphine_sulfate                                        0.316716
# drug_scopolamine_patch                                       0.236479
# lab_anion_gap                                                0.167270
# drug_lorazepam                                               0.163185
# drug_acetaminophen_iv                                        0.157659
# lab_potassium                                                0.152035
# vital_respiratory_rate                                       0.140027
# lab_lactate                                                  0.136531
# lab_rdw                                                      0.136367
# lab_pco2                                                     0.129934
# drug_mannitol_20_%                                           0.126893
# drug_chlorhexidine_gluconate_0.12%_oral_rinse                0.125230
# lab_urea_nitrogen                                            0.121874
# lab_specific_gravity                                         0.121684
# admission_location_TRANSFER FROM SKILLED NURSING FACILITY    0.111946
# drug_sodium_chloride_3%_(hypertonic)                         0.110937
# drug_propofol                                                0.110204
# insurance_Other                                              0.107086
#
# Top 20 NEGATIVE coefficients:
# vital_heart_rate_missing                                -0.335293
# lab_base_excess_missing                                 -0.302576
# admission_type_SURGICAL SAME DAY ADMISSION              -0.275878
# admission_location_INTERNAL TRANSFER TO OR FROM PSYCH   -0.267853
# procedure_5A1955Z                                       -0.252893
# procedure_02HV33Z                                       -0.206714
# procedure_966                                           -0.200976
# procedure_3E0G76Z                                       -0.188279
# drug_tacrolimus                                         -0.159323
# drug_warfarin                                           -0.154358
# procedure_02H633Z                                       -0.153026
# drug_heparin                                            -0.152314
# procedure_9672                                          -0.127548
# lab_platelet_count                                      -0.124683
# drug_dibucaine                                          -0.112431
# procedure_10D00Z1                                       -0.107348
# procedure_5A1D70Z                                       -0.104015
# procedure_009U3ZX                                       -0.102781
# procedure_4513                                          -0.101409
# admission_type_ELECTIVE                                 -0.101033
